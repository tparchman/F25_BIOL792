# %% [markdown]
# # Python primer 5, Data Science I.
#
# ## Topics to cover
#
# - more work with regular expressions
# - Input/Output: using loops to process many files at once.
# - Printing feedback statements using `sys.stderr.write()`
#
# ## Useful materials
#
# - regular expression cheat sheet (python-regular-expressions-cheat-sheet-1.pdf), regular expression appendix
# - [regular expression tester](https://regex101.com).
#
# ## Expanding Input/Output options
#
# We have learned how to use `open()` to make file handles for reading and writing. For individual, or small numbers of files, this is straightforward by now. Over the last two weeks, you might have used statements such as below to open file handles for reading and writing:
#
# ```py
#     IN = open(sys.argv[1], 'r')
#     OUT = open("myout.txt", 'w')
#     IN = open("bird_genomes.fasta", 'r')
# ```
#
# This week we will write code built to process many files at once (as many as you like as a matter of fact). We will cover the use of two python libraries that will help us to do this: `sys` and `glob`.
#
# The primer will work through examples using `sys.argv` first (using python scripts, not jupyter), and then using `glob` second (for jupyter). As `sys.argv` itself is a list, we can use `for` to loop through that list, opening each file one at a time, and running whatever code is necessary. This won't actually be that much different than what you had done up until now, as it will just entail writing all of your code to work on each file inside of a `for` loop that works through the input argument list `sys.argv`.
#
# Let's imagine we have a directory with 1000 text files that all end in `.fasta`. We are writing a python script that will live in the same directory, and we want to write code that works on ALL of these files and can be executed from the command line as:
#
#     $ python fasta_cleaner.py *fasta
#
# ## Using `sys.argv` to process multiple files.
#
# **This is the best way to process many files at a time when writing and storing code in python scripts (not `jupyter`)**
#
# Remember, `sys.argv` is simply a list of strings provided on the command line when a python script is executed. For the example below, sys.argv[0] would be `file_proc.py`, `sys.argv[1]` would be `file1.txt`, `sys.argv[2]` would be `file2.txt`, and `sys.argv[3]` would be `file3.txt`.
#
#     $ python file_proc.py file1.txt file2.txt file2.txt
#
# So, opening file connections to each of those files simply requires a `for` loop to work through `sys.argv[1:]`, where `[1:]` means from the `1` element to the end of the list. Anytime you want to do this, something similar to below will do the trick.
#
# ```py
#     for filename in sys.argv[1:]:
#         IN = open(filename, 'r')
# ```
#
# To build on the above example, lets look at some code which illustrates how to open file connections in a `for` loop using `sys.argv`, and then looping through each file, one line at a time. I have added the print statement below in order to print each scalar (in this case, the file names provided as command line arguments) in the `sys.argv` list as the for loop iterates.
#
# ```py
#     import sys
#     for file in sys.argv[1:]:
# 	    print(file)
# 	    IN=open(file, 'r')
# 	    for Line in IN:
# 		    Line=Line.strip("\n")
# 		    print(Line)
# 	    IN.close()
# ```
# ## Adding statement to open and write to new files *each time through* the loop
#
# The code below is similar to above, but statements have been added to open a file to write to **each** time through the loop. This will create a new output file for each separate input file. So, if you processed 100 input files, you would create 100 output files.
#
# ```py
#     import sys
#     for file in sys.argv[1:]:
#         print(file)
#         IN=open(file, 'r')
#         OUT=open("out_" + file, 'w')
#         for Line in IN:
#             Line=Line.strip("\n")
#             OUT.write(Line + "\n")
#         IN.close()
#         OUT.close()
#
# ```
#
# Notice above in the statment `OUT=open("out_" + file, 'w')` is creating file names that have `out_` appended to the file name variables contained in `sys.argv`. This means that output files will match input file in filenames, albeit with `out` added as a prefix. Thus, if the code below was run, the files `out_file1.txt`, `out_file3.txt`, and `out_file3.txt` would be generated.
#
#     $ python file_proc.py file1.txt file2.txt file2.txt
#
# ## Reading multiple files, writing to a single file
#
# Writing data to a single file after extracting and processing data from multiple files is common. To control writing in this manner, the file handle for the file being written to simply needs to be created.
#
# ```py
#     import sys
#     OUT=open("out.txt", 'w')
#     for file in sys.argv[1:]:
# 	    print(file)
# 	    IN=open(file, 'r')
# 	    for Line in IN:
# 	    	Line=Line.strip("\n")
# 	    	OUT.write(Line + "\n")
# 	    IN.close()
#     OUT.close()
# ```
#
# ## Reading and writing safely with the `codecs` module
#
# When working with text files that come from **different operating systems**, **older programs**, or **international datasets**, it’s common to encounter problems with **character encodings** — for example, when a file contains accented letters, Unicode symbols, or non-UTF-8 characters.
#
# The `codecs` module provides a safe, consistent interface for reading and writing files with specific encodings, such as UTF-8, Latin-1, or ASCII. This helps prevent errors like `UnicodeDecodeError` when Python tries to open a file using the wrong default encoding.
#
#    The `codecs` library facilitates some safeguards on reading from files that may have multiple types of text embedded (ASCII, utf-8). For example, ASCII is often interpretted as utf-8, but the converse is not true. Using this library (or `io.open`) is a safer way to read in files that may have some strangeness. As time goes on, you will likely learn more on when you want to use alternative `open` functions, but for now just trust me. For this weeks data manipulation problem, you can save yourself a headache by using the code below to open file handles while looping through `sys.argv` or a filelist generated with `glob`.
#
# ```py
#     import codecs
#     import sys
#     OUT=open("out.txt", 'w')
#     for file in sys.argv[1:]:
# 	    IN = codecs.open(file, 'r', encoding='utf-8', errors='ignore')
# 	    for Line in IN:
# 		Line=Line.strip("\n")
# 		OUT.write(Line + "\n")
# 	    IN.close()
#     OUT.close()
# ```

# %% [markdown]
# ## Printing feedback using `sys.stderr.write()`
#
# Print statements are sometimes used to print messages to screen while a program is running, but they are also often used to print data meant be redirected to a file (using `>` or `>>`). `sys.stderr.write()` allows for printing to screen through a different stream, which wont interfere with output being generated with `print`. This is a useful function for sending updates to screen while your program is running, and is especially useful as a debugging tool. Usage is similar to `.write()`, as demonstrated below.
#
# ```py
#     import sys
#     for file in sys.argv[1:]:
# 	    sys.stderr.write("Processing file: %s \n" %(file))
# 	    IN=open(file, 'r')
# 	    OUT=open("out_"+ file, 'w')
# 	    sys.stderr.write("Opened file for writing: out_%s \n" %(file))
# ```

# %%
import sys
Nums = range(0,100,5)
for file in Nums:
    sys.stderr.write(f"Processing num: {file} \n" )
# Out:
# Processing num: 0
# Processing num: 5
# Processing num: 10
# Processing num: 15
# Processing num: 20
# Processing num: 25
# Processing num: 30
# Processing num: 35
# Processing num: 40
# Processing num: 45
# Processing num: 50
# Processing num: 55
# Processing num: 60
# Processing num: 65
# Processing num: 70
# Processing num: 75
# Processing num: 80
# Processing num: 85
# Processing num: 90
# Processing num: 95

# %% [markdown]
# ## Using the `glob` library to find and list many files from jupyter-notebooks
#
# When working with many data files — especially in directories full of `.fasta`, `.txt`, `.csv`, or `.gz` files — the `glob` library provides a simple way to search for files by pattern (using wildcards like `*` and `?`). It is part of Python’s standard library, so you don’t need to install anything, just need to use `import` to call it into use.
#
# Unlike `sys.argv`, which requires you to pass filenames as command-line arguments, `glob` lets you find and process files directly from inside a script or notebook, making it more flexible for exploratory or interactive work.

# %%
import glob

files = glob.glob("*txt")
print(files)
# Out:
# ['outtest2.txt.txt', 'test1.txt.txt', 'test2.txt.txt', 'outtest1.txt.txt']

# %% [markdown]
# `glob` can also be used to search through subdirectories. The ** wildcard (with recursive=True) searches through the subdirectory logfiles, which has data files for this weeks programming task.
#
# You can use code structured like this to access files anywhere in your system.

# %%
files = glob.glob("logfiles/*.txt.gz", recursive=True)
#print(files)
print(len(files), "text files found.")
# Out:
# ['logfiles/1901302108_H7_D_13.txt.txt.gz', 'logfiles/1901302141_H19_S_13.txt.txt.gz', 'logfiles/1901302121_H8_S_14.txt.txt.gz', 'logfiles/1901302212_H9_D_13.txt.txt.gz', 'logfiles/1901302122_H3_D_13.txt.txt.gz', 'logfiles/1901302138_H11_D_13.txt.txt.gz', 'logfiles/1901302214_H19_D_14.txt.txt.gz', 'logfiles/1901302217_H18_D_13.txt.txt.gz', 'logfiles/1901302227_H11_S_14.txt.txt.gz', 'logfiles/1901302225_H12_D_13.txt.txt.gz', 'logfiles/1901302118_H1_D_14.txt.txt.gz', 'logfiles/1901302109_H7_S_13.txt.txt.gz', 'logfiles/1901302146_H14_D_13.txt.txt.gz', 'logfiles/1901302221_H6_D_13.txt.txt.gz', 'logfiles/1901302224_H3_S_14.txt.txt.gz', 'logfiles/1901302223_H16_S_14.txt.txt.gz', 'logfiles/1901302203_H7_S_14.txt.txt.gz', 'logfiles/1901302235_H6_S_14.txt.txt.gz', 'logfiles/1901302222_H2_S_14.txt.txt.gz', 'logfiles/1901302228_H4_D_14.txt.txt.gz', 'logfiles/1901302228_H4_D_13.txt.txt.gz', 'logfiles/1901302222_H2_S_13.txt.txt.gz', 'logfiles/1901302235_H6_S_13.txt.txt.gz', 'logfiles/1901302203_H7
# ...

# %% [markdown]
# ## Why `glob` is great in Jupyter notebooks
#
# - You don’t need to rerun your notebook with new command-line arguments — just rerun the cell after adding new files to your directory.
#
# - It works naturally with tab completion and dynamic inspection (print(glob.glob("*"))).
#
# - You can easily verify which files were found before opening them, avoiding errors.
#
# - It’s an excellent interactive alternative to sys.argv for early exploratory data analysis.

# %% [markdown]
# ## Using `glob` to process command line arguments in jupyter notebooks.
#
# The code provided below will help you get started on the programming task for this week.
#
# - Code below will store all filenames in the current directory ending in `.txt.txt` into `filelist`
# - The files you are attempting to access MUST reside in the same directory as this jupyter notebook.
# - `for` loop below is just printing elements of the list to confirm this is working as expected.
# - After storing all file names in `filelist`, you can use a `for` loop to open file handles to each file, one at a time.
# - `codecs.open` is used below, remember, to deal with some of the nasty hidden characters that might exist in files (specifically related to this weeks project).

# %%
import codecs
import glob

Filelist = glob.glob('*.txt.txt')
for Filename in Filelist:
    print(Filename)
    OUT = open("out_" + Filename, 'w')
    IN = codecs.open(Filename, 'r', encoding='utf-8', errors='ignore')
    for Line in IN:
        Line = Line.strip("\n")
        print("file is: ", Filename, "line is: ", Line)
        OUT.write("file is: %s , line is:  %s \n" % (Filename, Line))

    OUT.close()
# Out:
# test1.txt.txt
# file is:  test1.txt.txt line is:  1
# file is:  test1.txt.txt line is:  2
# file is:  test1.txt.txt line is:  44
# file is:  test1.txt.txt line is:  3
# file is:  test1.txt.txt line is:  gCFVV
# file is:  test1.txt.txt line is:  3
# file is:  test1.txt.txt line is:  4
# test2.txt.txt
# file is:  test2.txt.txt line is:  Joe
# file is:  test2.txt.txt line is:  Joe
# file is:  test2.txt.txt line is:  Tee
# file is:  test2.txt.txt line is:  Jamarr
# file is:  test2.txt.txt line is:  Jonah
# file is:  test2.txt.txt line is:  Cordell
# file is:  test2.txt.txt line is:  Orlando
# file is:  test2.txt.txt line is:  Ted
# file is:  test2.txt.txt line is:  Alex
# file is:  test2.txt.txt line is:  Irv
# file is:  test2.txt.txt line is:  Tyler

# %% [markdown]
# ## Commonly Used Regular expression symbols and metacharacters
#
# | **Symbol / expression** | **Meaning** | **Example** | **Matches** |
# |--------------------------|-------------|--------------|--------------|
# | `.` | Any single character (except newline) | `r"A.C"` | `"ATC"`, `"AAC"`, `"ACC"` |
# | `^` | Start of string or line | `r"^ATG"` | `"ATG..."` only if it appears at start |
# | `$` | End of string or line | `r"TAA$"` | Matches `"TAA"` only if it ends the line |
# | `[ ]` | Character class | `r"[ATGC]"` | Any one of `A`, `T`, `G`, or `C` |
# | `[^ ]` | Negated class | `r"[^0-9]"` | Any character **not** a digit |
# | `*` | 0 or more repetitions | `r"A*"` | `""`, `"A"`, `"AA"`, `"AAA"` |
# | `+` | 1 or more repetitions | `r"A+"` | `"A"`, `"AA"`, `"AAA"` |
# | `?` | 0 or 1 repetition | `r"AT?G"` | `"AG"` or `"ATG"` |
# | `{m}` | Exactly *m* repetitions | `r"A{3}"` | `"AAA"` |
# | `{m,n}` | Between *m* and *n* repetitions | `r"A{2,4}"` | `"AA"`, `"AAA"`, `"AAAA"` |
# | `|` | Logical OR | `r"A|T"` | Matches `"A"` or `"T"` |
# | `( )` | Grouping / capture | `r"(ATG)+"` | One or more `"ATG"` repeats |
# | `\d` | Any digit | `r"\d+"` | `"123"`, `"007"` |
# | `\D` | Any non-digit | `r"\D"` | `"A"`, `"_"` |
# | `\w` | Any alphanumeric character | `r"\w+"` | `"A1B2"`, `"gene123"` |
# | `\W` | Any non-alphanumeric | `r"\W+"` | `"@"`, `"#"`, `"%"` |
# | `\s` | Whitespace (space, tab, newline) | `r"\s+"` | `" "`, `"\t"`, `"\n"` |
# | `\S` | Non-whitespace | `r"\S+"` | `"ATGC"`, `"gene"` |
#
# ---
