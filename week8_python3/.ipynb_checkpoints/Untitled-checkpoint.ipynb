# %%
IN=open("genenames.txt", 'r')
#IN.readline()
IN.readlines()
# Out:
# ['WD1298\trpoD\n',
#  'WD1303\trpoZ\n',
#  'WD1306\tmutL-1\n',
#  'WD1309\tsucA\n',
#  'WD1316\tubiA\n',
#  'WD1318\tinfB\n']
