# %%
IN=open("genenames.txt", 'r')
#IN.readline()
#IN.readlines()
#IN.read()

for dog in IN:
    dline = dog.strip("\n")
    print(dog)
# Out:
# WD1295	carB
#
# WD1298	rpoD
#
# WD1303	rpoZ
#
# WD1306	mutL-1
#
# WD1309	sucA
#
# WD1316	ubiA
#
# WD1318	infB
