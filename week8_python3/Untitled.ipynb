# %%
import re

IN=open("no60_intron_IME_data.fasta", 'r')
IN.readline()
#IN.readlines()
#IN.read()

seqno = 0 
for line in IN:
    if re.search("^>", line):
        id = line
        seqno += 1
    elif re.search([ATCG], line):
# Out:
# '>AT1G68260.1_i1_204_CDS\n'
